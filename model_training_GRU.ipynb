# %% [markdown]
# # Model Use: *GRU*

# %% [markdown]
# # 1. Environement Setup

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, GRU, Dense
from sklearn.model_selection import train_test_split

file_path = 'normalized_output.csv'

# %% [markdown]
# # 2. Data Processing

# %%
# Load the data
data = pd.read_csv(file_path)

# Function to convert string representation of a list to an actual list
def convert_string_to_list(string):
    return np.fromstring(string[1:-1], sep=',') 

X = np.array([convert_string_to_list(row) for row in data['ph_seq_encoded']])
y_note = np.array([convert_string_to_list(row) for row in data['note_seq_encoded']])
y_dur = np.array([convert_string_to_list(row) for row in data['ph_dur']])

# Reshape the arrays
X_reshaped = X.reshape((X.shape[0], X.shape[1], 1))
y_note_reshaped = y_note.reshape((y_note.shape[0], y_note.shape[1], 1))
y_dur_reshaped = y_dur.reshape((y_dur.shape[0], y_dur.shape[1], 1))

# print(X_reshaped[0].dtype, y_note_reshaped[0].dtype, y_dur_reshaped[0].dtype)

# Split the data into training and test sets
X_train, X_test, y_note_train, y_note_test, y_dur_train, y_dur_test = train_test_split(
    X_reshaped, y_note_reshaped, y_dur_reshaped, test_size=0.3, random_state=42)

y_dur_train.shape
# Out:
# (2815, 283, 1)

# %% [markdown]
# # 3. Model Training

# %%
# Input layer
input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))

# GRU layers
gru1 = GRU(64, return_sequences=True)(input_layer)
gru2 = GRU(32, return_sequences=True)(gru1)

# Output layers for y_note
y_note_output = Dense(10, activation='relu')(gru2)
y_note_output = Dense(1, activation='sigmoid', name='y_note_output')(y_note_output)

# Output layers for y_dur
y_dur_output = Dense(10, activation='relu')(gru2)
y_dur_output = Dense(1, activation='sigmoid', name='y_dur_output')(y_dur_output)

# Building the model
model = Model(inputs=input_layer, outputs=[y_note_output, y_dur_output])

# Compiling the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Training the model
history = model.fit(X_train, [y_note_train, y_dur_train], epochs=200, batch_size=64, validation_split=0.2)

# Evaluate the model on the test set
test_loss = model.evaluate(X_test, [y_note_test, y_dur_test])
# Out:
# Epoch 1/200
# 36/36 [==============================] - 12s 224ms/step - loss: 0.0736 - y_note_output_loss: 0.0162 - y_dur_output_loss: 0.0575 - val_loss: 0.0611 - val_y_note_output_loss: 0.0142 - val_y_dur_output_loss: 0.0469
# Epoch 2/200
# 36/36 [==============================] - 7s 196ms/step - loss: 0.0694 - y_note_output_loss: 0.0154 - y_dur_output_loss: 0.0540 - val_loss: 0.0594 - val_y_note_output_loss: 0.0141 - val_y_dur_output_loss: 0.0453
# Epoch 3/200
# 36/36 [==============================] - 7s 195ms/step - loss: 0.0671 - y_note_output_loss: 0.0148 - y_dur_output_loss: 0.0523 - val_loss: 0.0579 - val_y_note_output_loss: 0.0137 - val_y_dur_output_loss: 0.0441
# Epoch 4/200
# 36/36 [==============================] - 7s 196ms/step - loss: 0.0647 - y_note_output_loss: 0.0146 - y_dur_output_loss: 0.0501 - val_loss: 0.0560 - val_y_note_output_loss: 0.0137 - val_y_dur_output_loss: 0.0423
# Epoch 5/200
# 36/36 [==============================] - 7s 195ms/step - loss: 0.0632 - y_note_output_loss: 0.0143 - y_dur_output_loss: 0.0489 - val_loss: 0.0544 - val_y_note_output_loss: 0.0132 - val_y_dur_output_loss: 0.0412
# Epoch 6/200
# 36/36 [==============================] - 7s 197ms/step - loss: 0.0627 - y_note_output_loss: 0.0141 - y_dur_output_loss: 0.0486 - val_loss: 0.0535 - val_y_note_output_loss: 0.0132 - val_y_dur_output_loss: 0.0403
# Epoch 7/200
# 36/36 [==============================] - 7s 195ms/step - loss: 0.0608 - y_note_output_loss: 0.0141 - y_dur_output_loss: 0.0466 - val_loss: 0.0524 - val_y_note_output_loss: 0.0130 - val_y_dur_output_loss: 0.0394
# Epoch 8/200
# 36/36 [==============================] - 7s 196ms/step - loss: 0.0596 - y_note_output_loss: 0.0141 - y_dur_output_loss: 0.0455 - val_loss: 0.0566 - val_y_note_output_loss: 0.0135 - val_y_dur_output_loss: 0.0430
# Epoch 9/200
# 36/36 [==============================] - 7s 195ms/step - loss: 0.0579 - y_note_output_loss: 0.0139 - y_dur_output_loss: 0.0441 - val_loss: 0.0500 - val_y_note_output_loss: 0.0126 - val_y_dur_output_loss: 0.0374
# Epoch 10/200
# 36/36 [==============================] - 7s 196ms/step - loss: 0.0552 - y_note_output_loss: 0.0135 - y_dur_output_loss: 0.0418 - val_loss: 0.0482 - val_y_note_output_loss: 0.0123 - val_y_dur_output_loss: 0.0360
# Epoch 11/200
# 36/36 [==============================] - 7s 194ms/step - loss: 0.0538 - y_note_output_loss: 0.0133 - y_dur_output_loss: 0.0404 - val_loss: 0.0480 - val_y_note_output_loss: 0.0125 - val_y_dur_output_loss: 0.0356
# Epoch 12/200
# 36/36 [==============================] - 7s 195ms/step - loss: 0.0550 - y_note_output_loss: 0.0135 - y_dur_output_loss: 0.0415 - val_loss: 0.0474 - val_y_note_output_loss: 0.0125 - val_y_dur_output_loss: 0.0350
# Epoch 13/200
# 36/36 [==============================] - 7s 196ms/step - loss: 0.0527 - y_note_output_loss: 0.0135 - y_dur_output_loss: 0.0392 - val_loss: 0.0457 - val_y_note_output_loss: 0.0121 - val_y_dur_output_loss: 0.0336
# Epoch 14/200
# 36/36 [==============================] - 7s 194ms/step - loss: 0.0512 - y_note_output_loss: 0.0129 - y_dur_output_loss: 0.0383 - val_loss: 0.0468 - val_y_note_output_loss: 0.0126 - val_y_dur_output_loss: 0.0342
# Epoch 15/200
# 36/36 [==============================] - 7s 194ms/step - loss: 0.0498 - y_note_output_loss: 0.0129 - y_dur_output_loss: 0.0369 - val_loss: 0.0468 - val_y_note_output_loss: 0.0119 - val_y_dur_output_loss: 0.0349
# Epoch 16/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0491 - y_note_output_loss: 0.0126 - y_dur_output_loss: 0.0365 - val_loss: 0.0446 - val_y_note_output_loss: 0.0115 - val_y_dur_output_loss: 0.0331
# Epoch 17/200
# 36/36 [==============================] - 7s 201ms/step - loss: 0.0484 - y_note_output_loss: 0.0124 - y_dur_output_loss: 0.0360 - val_loss: 0.0463 - val_y_note_output_loss: 0.0116 - val_y_dur_output_loss: 0.0347
# Epoch 18/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0493 - y_note_output_loss: 0.0126 - y_dur_output_loss: 0.0367 - val_loss: 0.0464 - val_y_note_output_loss: 0.0116 - val_y_dur_output_loss: 0.0348
# Epoch 19/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0489 - y_note_output_loss: 0.0123 - y_dur_output_loss: 0.0365 - val_loss: 0.0449 - val_y_note_output_loss: 0.0115 - val_y_dur_output_loss: 0.0334
# Epoch 20/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0482 - y_note_output_loss: 0.0122 - y_dur_output_loss: 0.0360 - val_loss: 0.0447 - val_y_note_output_loss: 0.0112 - val_y_dur_output_loss: 0.0335
# Epoch 21/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0475 - y_note_output_loss: 0.0122 - y_dur_output_loss: 0.0352 - val_loss: 0.0434 - val_y_note_output_loss: 0.0109 - val_y_dur_output_loss: 0.0326
# Epoch 22/200
# 36/36 [==============================] - 7s 201ms/step - loss: 0.0468 - y_note_output_loss: 0.0118 - y_dur_output_loss: 0.0350 - val_loss: 0.0457 - val_y_note_output_loss: 0.0110 - val_y_dur_output_loss: 0.0347
# Epoch 23/200
# 36/36 [==============================] - 7s 201ms/step - loss: 0.0474 - y_note_output_loss: 0.0119 - y_dur_output_loss: 0.0354 - val_loss: 0.0436 - val_y_note_output_loss: 0.0108 - val_y_dur_output_loss: 0.0328
# Epoch 24/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0545 - y_note_output_loss: 0.0119 - y_dur_output_loss: 0.0426 - val_loss: 0.0526 - val_y_note_output_loss: 0.0114 - val_y_dur_output_loss: 0.0412
# Epoch 25/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0552 - y_note_output_loss: 0.0116 - y_dur_output_loss: 0.0436 - val_loss: 0.0452 - val_y_note_output_loss: 0.0106 - val_y_dur_output_loss: 0.0346
# Epoch 26/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0483 - y_note_output_loss: 0.0113 - y_dur_output_loss: 0.0370 - val_loss: 0.0429 - val_y_note_output_loss: 0.0104 - val_y_dur_output_loss: 0.0325
# Epoch 27/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0467 - y_note_output_loss: 0.0113 - y_dur_output_loss: 0.0354 - val_loss: 0.0429 - val_y_note_output_loss: 0.0102 - val_y_dur_output_loss: 0.0326
# Epoch 28/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0459 - y_note_output_loss: 0.0111 - y_dur_output_loss: 0.0348 - val_loss: 0.0431 - val_y_note_output_loss: 0.0102 - val_y_dur_output_loss: 0.0329
# Epoch 29/200
# 36/36 [==============================] - 7s 201ms/step - loss: 0.0473 - y_note_output_loss: 0.0111 - y_dur_output_loss: 0.0362 - val_loss: 0.0415 - val_y_note_output_loss: 0.0100 - val_y_dur_output_loss: 0.0315
# Epoch 30/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0460 - y_note_output_loss: 0.0110 - y_dur_output_loss: 0.0351 - val_loss: 0.0419 - val_y_note_output_loss: 0.0101 - val_y_dur_output_loss: 0.0317
# Epoch 31/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0452 - y_note_output_loss: 0.0109 - y_dur_output_loss: 0.0342 - val_loss: 0.0407 - val_y_note_output_loss: 0.0098 - val_y_dur_output_loss: 0.0309
# Epoch 32/200
# 36/36 [==============================] - 7s 203ms/step - loss: 0.0444 - y_note_output_loss: 0.0106 - y_dur_output_loss: 0.0338 - val_loss: 0.0414 - val_y_note_output_loss: 0.0099 - val_y_dur_output_loss: 0.0315
# Epoch 33/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0446 - y_note_output_loss: 0.0105 - y_dur_output_loss: 0.0342 - val_loss: 0.0431 - val_y_note_output_loss: 0.0101 - val_y_dur_output_loss: 0.0330
# Epoch 34/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0449 - y_note_output_loss: 0.0105 - y_dur_output_loss: 0.0343 - val_loss: 0.0420 - val_y_note_output_loss: 0.0100 - val_y_dur_output_loss: 0.0320
# Epoch 35/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0444 - y_note_output_loss: 0.0104 - y_dur_output_loss: 0.0340 - val_loss: 0.0425 - val_y_note_output_loss: 0.0098 - val_y_dur_output_loss: 0.0327
# Epoch 36/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0438 - y_note_output_loss: 0.0104 - y_dur_output_loss: 0.0334 - val_loss: 0.0407 - val_y_note_output_loss: 0.0096 - val_y_dur_output_loss: 0.0311
# Epoch 37/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0436 - y_note_output_loss: 0.0103 - y_dur_output_loss: 0.0333 - val_loss: 0.0416 - val_y_note_output_loss: 0.0097 - val_y_dur_output_loss: 0.0319
# Epoch 38/200
# 36/36 [==============================] - 7s 198ms/step - loss: 0.0440 - y_note_output_loss: 0.0101 - y_dur_output_loss: 0.0338 - val_loss: 0.0403 - val_y_note_output_loss: 0.0093 - val_y_dur_output_loss: 0.0310
# Epoch 39/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0433 - y_note_output_loss: 0.0099 - y_dur_output_loss: 0.0334 - val_loss: 0.0402 - val_y_note_output_loss: 0.0093 - val_y_dur_output_loss: 0.0309
# Epoch 40/200
# 36/36 [==============================] - 7s 203ms/step - loss: 0.0442 - y_note_output_loss: 0.0100 - y_dur_output_loss: 0.0342 - val_loss: 0.0420 - val_y_note_output_loss: 0.0092 - val_y_dur_output_loss: 0.0327
# Epoch 41/200
# 36/36 [==============================] - 7s 201ms/step - loss: 0.0440 - y_note_output_loss: 0.0099 - y_dur_output_loss: 0.0341 - val_loss: 0.0398 - val_y_note_output_loss: 0.0092 - val_y_dur_output_loss: 0.0306
# Epoch 42/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0426 - y_note_output_loss: 0.0098 - y_dur_output_loss: 0.0328 - val_loss: 0.0395 - val_y_note_output_loss: 0.0092 - val_y_dur_output_loss: 0.0303
# Epoch 43/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0427 - y_note_output_loss: 0.0097 - y_dur_output_loss: 0.0331 - val_loss: 0.0404 - val_y_note_output_loss: 0.0091 - val_y_dur_output_loss: 0.0313
# Epoch 44/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0420 - y_note_output_loss: 0.0096 - y_dur_output_loss: 0.0324 - val_loss: 0.0394 - val_y_note_output_loss: 0.0089 - val_y_dur_output_loss: 0.0305
# Epoch 45/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0421 - y_note_output_loss: 0.0095 - y_dur_output_loss: 0.0326 - val_loss: 0.0403 - val_y_note_output_loss: 0.0095 - val_y_dur_output_loss: 0.0308
# Epoch 46/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0421 - y_note_output_loss: 0.0096 - y_dur_output_loss: 0.0325 - val_loss: 0.0403 - val_y_note_output_loss: 0.0088 - val_y_dur_output_loss: 0.0315
# Epoch 47/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0418 - y_note_output_loss: 0.0094 - y_dur_output_loss: 0.0324 - val_loss: 0.0391 - val_y_note_output_loss: 0.0089 - val_y_dur_output_loss: 0.0303
# Epoch 48/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0417 - y_note_output_loss: 0.0093 - y_dur_output_loss: 0.0324 - val_loss: 0.0396 - val_y_note_output_loss: 0.0093 - val_y_dur_output_loss: 0.0302
# Epoch 49/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0420 - y_note_output_loss: 0.0092 - y_dur_output_loss: 0.0328 - val_loss: 0.0382 - val_y_note_output_loss: 0.0087 - val_y_dur_output_loss: 0.0295
# Epoch 50/200
# 36/36 [==============================] - 7s 201ms/step - loss: 0.0416 - y_note_output_loss: 0.0092 - y_dur_output_loss: 0.0324 - val_loss: 0.0403 - val_y_note_output_loss: 0.0096 - val_y_dur_output_loss: 0.0307
# Epoch 51/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0413 - y_note_output_loss: 0.0093 - y_dur_output_loss: 0.0321 - val_loss: 0.0393 - val_y_note_output_loss: 0.0091 - val_y_dur_output_loss: 0.0302
# Epoch 52/200
# 36/36 [==============================] - 7s 201ms/step - loss: 0.0417 - y_note_output_loss: 0.0093 - y_dur_output_loss: 0.0324 - val_loss: 0.0393 - val_y_note_output_loss: 0.0085 - val_y_dur_output_loss: 0.0308
# Epoch 53/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0409 - y_note_output_loss: 0.0090 - y_dur_output_loss: 0.0319 - val_loss: 0.0394 - val_y_note_output_loss: 0.0086 - val_y_dur_output_loss: 0.0309
# Epoch 54/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0409 - y_note_output_loss: 0.0089 - y_dur_output_loss: 0.0320 - val_loss: 0.0393 - val_y_note_output_loss: 0.0087 - val_y_dur_output_loss: 0.0306
# Epoch 55/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0413 - y_note_output_loss: 0.0090 - y_dur_output_loss: 0.0324 - val_loss: 0.0376 - val_y_note_output_loss: 0.0085 - val_y_dur_output_loss: 0.0290
# Epoch 56/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0406 - y_note_output_loss: 0.0089 - y_dur_output_loss: 0.0318 - val_loss: 0.0390 - val_y_note_output_loss: 0.0087 - val_y_dur_output_loss: 0.0303
# Epoch 57/200
# 36/36 [==============================] - 7s 201ms/step - loss: 0.0417 - y_note_output_loss: 0.0090 - y_dur_output_loss: 0.0327 - val_loss: 0.0394 - val_y_note_output_loss: 0.0082 - val_y_dur_output_loss: 0.0311
# Epoch 58/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0421 - y_note_output_loss: 0.0090 - y_dur_output_loss: 0.0331 - val_loss: 0.0386 - val_y_note_output_loss: 0.0086 - val_y_dur_output_loss: 0.0301
# Epoch 59/200
# 36/36 [==============================] - 7s 202ms/step - loss: 0.0408 - y_note_output_loss: 0.0088 - y_dur_output_loss: 0.0320 - val_loss: 0.0522 - val_y_note_output_loss: 0.0101 - val_y_dur_output_loss: 0.0421
# Epoch 60/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0660 - y_note_output_loss: 0.0108 - y_dur_output_loss: 0.0552 - val_loss: 0.0532 - val_y_note_output_loss: 0.0090 - val_y_dur_output_loss: 0.0442
# Epoch 61/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0605 - y_note_output_loss: 0.0095 - y_dur_output_loss: 0.0510 - val_loss: 0.0492 - val_y_note_output_loss: 0.0087 - val_y_dur_output_loss: 0.0405
# Epoch 62/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0545 - y_note_output_loss: 0.0093 - y_dur_output_loss: 0.0452 - val_loss: 0.0446 - val_y_note_output_loss: 0.0084 - val_y_dur_output_loss: 0.0362
# Epoch 63/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0488 - y_note_output_loss: 0.0089 - y_dur_output_loss: 0.0400 - val_loss: 0.0420 - val_y_note_output_loss: 0.0084 - val_y_dur_output_loss: 0.0337
# Epoch 64/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0456 - y_note_output_loss: 0.0087 - y_dur_output_loss: 0.0368 - val_loss: 0.0403 - val_y_note_output_loss: 0.0086 - val_y_dur_output_loss: 0.0317
# Epoch 65/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0440 - y_note_output_loss: 0.0086 - y_dur_output_loss: 0.0354 - val_loss: 0.0388 - val_y_note_output_loss: 0.0079 - val_y_dur_output_loss: 0.0309
# Epoch 66/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0432 - y_note_output_loss: 0.0087 - y_dur_output_loss: 0.0345 - val_loss: 0.0395 - val_y_note_output_loss: 0.0079 - val_y_dur_output_loss: 0.0317
# Epoch 67/200
# 36/36 [==============================] - 7s 198ms/step - loss: 0.0448 - y_note_output_loss: 0.0089 - y_dur_output_loss: 0.0359 - val_loss: 0.0440 - val_y_note_output_loss: 0.0082 - val_y_dur_output_loss: 0.0358
# Epoch 68/200
# 36/36 [==============================] - 7s 202ms/step - loss: 0.0438 - y_note_output_loss: 0.0088 - y_dur_output_loss: 0.0349 - val_loss: 0.0380 - val_y_note_output_loss: 0.0081 - val_y_dur_output_loss: 0.0299
# Epoch 69/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0419 - y_note_output_loss: 0.0087 - y_dur_output_loss: 0.0332 - val_loss: 0.0391 - val_y_note_output_loss: 0.0081 - val_y_dur_output_loss: 0.0311
# Epoch 70/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0417 - y_note_output_loss: 0.0084 - y_dur_output_loss: 0.0333 - val_loss: 0.0378 - val_y_note_output_loss: 0.0082 - val_y_dur_output_loss: 0.0297
# Epoch 71/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0412 - y_note_output_loss: 0.0084 - y_dur_output_loss: 0.0329 - val_loss: 0.0374 - val_y_note_output_loss: 0.0081 - val_y_dur_output_loss: 0.0293
# Epoch 72/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0409 - y_note_output_loss: 0.0082 - y_dur_output_loss: 0.0328 - val_loss: 0.0383 - val_y_note_output_loss: 0.0079 - val_y_dur_output_loss: 0.0304
# Epoch 73/200
# 36/36 [==============================] - 7s 198ms/step - loss: 0.0416 - y_note_output_loss: 0.0084 - y_dur_output_loss: 0.0333 - val_loss: 0.0374 - val_y_note_output_loss: 0.0081 - val_y_dur_output_loss: 0.0293
# Epoch 74/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0437 - y_note_output_loss: 0.0086 - y_dur_output_loss: 0.0351 - val_loss: 0.0377 - val_y_note_output_loss: 0.0079 - val_y_dur_output_loss: 0.0298
# Epoch 75/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0426 - y_note_output_loss: 0.0084 - y_dur_output_loss: 0.0342 - val_loss: 0.0378 - val_y_note_output_loss: 0.0078 - val_y_dur_output_loss: 0.0299
# Epoch 76/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0418 - y_note_output_loss: 0.0083 - y_dur_output_loss: 0.0334 - val_loss: 0.0371 - val_y_note_output_loss: 0.0081 - val_y_dur_output_loss: 0.0290
# Epoch 77/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0404 - y_note_output_loss: 0.0082 - y_dur_output_loss: 0.0323 - val_loss: 0.0369 - val_y_note_output_loss: 0.0080 - val_y_dur_output_loss: 0.0289
# Epoch 78/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0405 - y_note_output_loss: 0.0083 - y_dur_output_loss: 0.0322 - val_loss: 0.0387 - val_y_note_output_loss: 0.0084 - val_y_dur_output_loss: 0.0303
# Epoch 79/200
# 36/36 [==============================] - 7s 198ms/step - loss: 0.0408 - y_note_output_loss: 0.0083 - y_dur_output_loss: 0.0325 - val_loss: 0.0371 - val_y_note_output_loss: 0.0080 - val_y_dur_output_loss: 0.0292
# Epoch 80/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0404 - y_note_output_loss: 0.0081 - y_dur_output_loss: 0.0323 - val_loss: 0.0377 - val_y_note_output_loss: 0.0079 - val_y_dur_output_loss: 0.0298
# Epoch 81/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0398 - y_note_output_loss: 0.0080 - y_dur_output_loss: 0.0318 - val_loss: 0.0374 - val_y_note_output_loss: 0.0083 - val_y_dur_output_loss: 0.0291
# Epoch 82/200
# 36/36 [==============================] - 7s 202ms/step - loss: 0.0403 - y_note_output_loss: 0.0082 - y_dur_output_loss: 0.0321 - val_loss: 0.0367 - val_y_note_output_loss: 0.0080 - val_y_dur_output_loss: 0.0288
# Epoch 83/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0396 - y_note_output_loss: 0.0080 - y_dur_output_loss: 0.0316 - val_loss: 0.0382 - val_y_note_output_loss: 0.0083 - val_y_dur_output_loss: 0.0298
# Epoch 84/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0397 - y_note_output_loss: 0.0081 - y_dur_output_loss: 0.0316 - val_loss: 0.0365 - val_y_note_output_loss: 0.0080 - val_y_dur_output_loss: 0.0285
# Epoch 85/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0403 - y_note_output_loss: 0.0084 - y_dur_output_loss: 0.0319 - val_loss: 0.0368 - val_y_note_output_loss: 0.0081 - val_y_dur_output_loss: 0.0288
# Epoch 86/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0400 - y_note_output_loss: 0.0082 - y_dur_output_loss: 0.0319 - val_loss: 0.0371 - val_y_note_output_loss: 0.0085 - val_y_dur_output_loss: 0.0286
# Epoch 87/200
# 36/36 [==============================] - 7s 201ms/step - loss: 0.0398 - y_note_output_loss: 0.0081 - y_dur_output_loss: 0.0316 - val_loss: 0.0377 - val_y_note_output_loss: 0.0080 - val_y_dur_output_loss: 0.0297
# Epoch 88/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0394 - y_note_output_loss: 0.0081 - y_dur_output_loss: 0.0313 - val_loss: 0.0367 - val_y_note_output_loss: 0.0080 - val_y_dur_output_loss: 0.0287
# Epoch 89/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0392 - y_note_output_loss: 0.0081 - y_dur_output_loss: 0.0311 - val_loss: 0.0367 - val_y_note_output_loss: 0.0080 - val_y_dur_output_loss: 0.0287
# Epoch 90/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0393 - y_note_output_loss: 0.0084 - y_dur_output_loss: 0.0310 - val_loss: 0.0362 - val_y_note_output_loss: 0.0081 - val_y_dur_output_loss: 0.0281
# Epoch 91/200
# 36/36 [==============================] - 7s 201ms/step - loss: 0.0390 - y_note_output_loss: 0.0080 - y_dur_output_loss: 0.0311 - val_loss: 0.0370 - val_y_note_output_loss: 0.0086 - val_y_dur_output_loss: 0.0284
# Epoch 92/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0390 - y_note_output_loss: 0.0080 - y_dur_output_loss: 0.0311 - val_loss: 0.0363 - val_y_note_output_loss: 0.0078 - val_y_dur_output_loss: 0.0284
# Epoch 93/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0388 - y_note_output_loss: 0.0080 - y_dur_output_loss: 0.0308 - val_loss: 0.0372 - val_y_note_output_loss: 0.0086 - val_y_dur_output_loss: 0.0287
# Epoch 94/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0390 - y_note_output_loss: 0.0082 - y_dur_output_loss: 0.0308 - val_loss: 0.0378 - val_y_note_output_loss: 0.0084 - val_y_dur_output_loss: 0.0294
# Epoch 95/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0392 - y_note_output_loss: 0.0083 - y_dur_output_loss: 0.0309 - val_loss: 0.0366 - val_y_note_output_loss: 0.0079 - val_y_dur_output_loss: 0.0286
# Epoch 96/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0383 - y_note_output_loss: 0.0080 - y_dur_output_loss: 0.0304 - val_loss: 0.0382 - val_y_note_output_loss: 0.0088 - val_y_dur_output_loss: 0.0294
# Epoch 97/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0391 - y_note_output_loss: 0.0083 - y_dur_output_loss: 0.0308 - val_loss: 0.0368 - val_y_note_output_loss: 0.0080 - val_y_dur_output_loss: 0.0287
# Epoch 98/200
# 36/36 [==============================] - 7s 198ms/step - loss: 0.0384 - y_note_output_loss: 0.0080 - y_dur_output_loss: 0.0304 - val_loss: 0.0380 - val_y_note_output_loss: 0.0082 - val_y_dur_output_loss: 0.0298
# Epoch 99/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0389 - y_note_output_loss: 0.0081 - y_dur_output_loss: 0.0308 - val_loss: 0.0360 - val_y_note_output_loss: 0.0081 - val_y_dur_output_loss: 0.0279
# Epoch 100/200
# 36/36 [==============================] - 7s 201ms/step - loss: 0.0382 - y_note_output_loss: 0.0079 - y_dur_output_loss: 0.0303 - val_loss: 0.0364 - val_y_note_output_loss: 0.0084 - val_y_dur_output_loss: 0.0280
# Epoch 101/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0382 - y_note_output_loss: 0.0081 - y_dur_output_loss: 0.0301 - val_loss: 0.0356 - val_y_note_output_loss: 0.0078 - val_y_dur_output_loss: 0.0278
# Epoch 102/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0382 - y_note_output_loss: 0.0080 - y_dur_output_loss: 0.0302 - val_loss: 0.0386 - val_y_note_output_loss: 0.0080 - val_y_dur_output_loss: 0.0306
# Epoch 103/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0397 - y_note_output_loss: 0.0085 - y_dur_output_loss: 0.0312 - val_loss: 0.0366 - val_y_note_output_loss: 0.0083 - val_y_dur_output_loss: 0.0283
# Epoch 104/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0380 - y_note_output_loss: 0.0079 - y_dur_output_loss: 0.0300 - val_loss: 0.0362 - val_y_note_output_loss: 0.0081 - val_y_dur_output_loss: 0.0281
# Epoch 105/200
# 36/36 [==============================] - 7s 202ms/step - loss: 0.0389 - y_note_output_loss: 0.0081 - y_dur_output_loss: 0.0308 - val_loss: 0.0385 - val_y_note_output_loss: 0.0088 - val_y_dur_output_loss: 0.0297
# Epoch 106/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0383 - y_note_output_loss: 0.0081 - y_dur_output_loss: 0.0302 - val_loss: 0.0359 - val_y_note_output_loss: 0.0079 - val_y_dur_output_loss: 0.0280
# Epoch 107/200
# 36/36 [==============================] - 7s 202ms/step - loss: 0.0376 - y_note_output_loss: 0.0079 - y_dur_output_loss: 0.0298 - val_loss: 0.0354 - val_y_note_output_loss: 0.0077 - val_y_dur_output_loss: 0.0277
# Epoch 108/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0375 - y_note_output_loss: 0.0078 - y_dur_output_loss: 0.0298 - val_loss: 0.0361 - val_y_note_output_loss: 0.0080 - val_y_dur_output_loss: 0.0281
# Epoch 109/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0382 - y_note_output_loss: 0.0081 - y_dur_output_loss: 0.0301 - val_loss: 0.0360 - val_y_note_output_loss: 0.0082 - val_y_dur_output_loss: 0.0277
# Epoch 110/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0376 - y_note_output_loss: 0.0080 - y_dur_output_loss: 0.0296 - val_loss: 0.0362 - val_y_note_output_loss: 0.0079 - val_y_dur_output_loss: 0.0283
# Epoch 111/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0376 - y_note_output_loss: 0.0078 - y_dur_output_loss: 0.0297 - val_loss: 0.0364 - val_y_note_output_loss: 0.0083 - val_y_dur_output_loss: 0.0281
# Epoch 112/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0371 - y_note_output_loss: 0.0078 - y_dur_output_loss: 0.0294 - val_loss: 0.0356 - val_y_note_output_loss: 0.0079 - val_y_dur_output_loss: 0.0277
# Epoch 113/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0377 - y_note_output_loss: 0.0079 - y_dur_output_loss: 0.0298 - val_loss: 0.0384 - val_y_note_output_loss: 0.0097 - val_y_dur_output_loss: 0.0287
# Epoch 114/200
# 36/36 [==============================] - 7s 202ms/step - loss: 0.0378 - y_note_output_loss: 0.0081 - y_dur_output_loss: 0.0297 - val_loss: 0.0366 - val_y_note_output_loss: 0.0085 - val_y_dur_output_loss: 0.0281
# Epoch 115/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0371 - y_note_output_loss: 0.0078 - y_dur_output_loss: 0.0293 - val_loss: 0.0366 - val_y_note_output_loss: 0.0080 - val_y_dur_output_loss: 0.0286
# Epoch 116/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0382 - y_note_output_loss: 0.0083 - y_dur_output_loss: 0.0298 - val_loss: 0.0354 - val_y_note_output_loss: 0.0080 - val_y_dur_output_loss: 0.0273
# Epoch 117/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0373 - y_note_output_loss: 0.0078 - y_dur_output_loss: 0.0295 - val_loss: 0.0356 - val_y_note_output_loss: 0.0082 - val_y_dur_output_loss: 0.0274
# Epoch 118/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0374 - y_note_output_loss: 0.0080 - y_dur_output_loss: 0.0294 - val_loss: 0.0361 - val_y_note_output_loss: 0.0079 - val_y_dur_output_loss: 0.0282
# Epoch 119/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0373 - y_note_output_loss: 0.0081 - y_dur_output_loss: 0.0292 - val_loss: 0.0377 - val_y_note_output_loss: 0.0090 - val_y_dur_output_loss: 0.0286
# Epoch 120/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0369 - y_note_output_loss: 0.0079 - y_dur_output_loss: 0.0290 - val_loss: 0.0370 - val_y_note_output_loss: 0.0078 - val_y_dur_output_loss: 0.0293
# Epoch 121/200
# 36/36 [==============================] - 7s 201ms/step - loss: 0.0368 - y_note_output_loss: 0.0078 - y_dur_output_loss: 0.0290 - val_loss: 0.0349 - val_y_note_output_loss: 0.0079 - val_y_dur_output_loss: 0.0271
# Epoch 122/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0367 - y_note_output_loss: 0.0079 - y_dur_output_loss: 0.0288 - val_loss: 0.0352 - val_y_note_output_loss: 0.0080 - val_y_dur_output_loss: 0.0272
# Epoch 123/200
# 36/36 [==============================] - 7s 201ms/step - loss: 0.0363 - y_note_output_loss: 0.0077 - y_dur_output_loss: 0.0286 - val_loss: 0.0367 - val_y_note_output_loss: 0.0077 - val_y_dur_output_loss: 0.0290
# Epoch 124/200
# 36/36 [==============================] - 7s 202ms/step - loss: 0.0412 - y_note_output_loss: 0.0084 - y_dur_output_loss: 0.0328 - val_loss: 0.0368 - val_y_note_output_loss: 0.0090 - val_y_dur_output_loss: 0.0278
# Epoch 125/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0386 - y_note_output_loss: 0.0084 - y_dur_output_loss: 0.0302 - val_loss: 0.0368 - val_y_note_output_loss: 0.0085 - val_y_dur_output_loss: 0.0283
# Epoch 126/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0368 - y_note_output_loss: 0.0079 - y_dur_output_loss: 0.0289 - val_loss: 0.0355 - val_y_note_output_loss: 0.0078 - val_y_dur_output_loss: 0.0277
# Epoch 127/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0366 - y_note_output_loss: 0.0080 - y_dur_output_loss: 0.0286 - val_loss: 0.0356 - val_y_note_output_loss: 0.0079 - val_y_dur_output_loss: 0.0277
# Epoch 128/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0368 - y_note_output_loss: 0.0077 - y_dur_output_loss: 0.0291 - val_loss: 0.0356 - val_y_note_output_loss: 0.0083 - val_y_dur_output_loss: 0.0273
# Epoch 129/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0365 - y_note_output_loss: 0.0077 - y_dur_output_loss: 0.0287 - val_loss: 0.0362 - val_y_note_output_loss: 0.0081 - val_y_dur_output_loss: 0.0281
# Epoch 130/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0364 - y_note_output_loss: 0.0079 - y_dur_output_loss: 0.0285 - val_loss: 0.0361 - val_y_note_output_loss: 0.0079 - val_y_dur_output_loss: 0.0282
# Epoch 131/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0363 - y_note_output_loss: 0.0078 - y_dur_output_loss: 0.0285 - val_loss: 0.0365 - val_y_note_output_loss: 0.0083 - val_y_dur_output_loss: 0.0282
# Epoch 132/200
# 36/36 [==============================] - 7s 202ms/step - loss: 0.0361 - y_note_output_loss: 0.0078 - y_dur_output_loss: 0.0283 - val_loss: 0.0367 - val_y_note_output_loss: 0.0081 - val_y_dur_output_loss: 0.0286
# Epoch 133/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0364 - y_note_output_loss: 0.0077 - y_dur_output_loss: 0.0287 - val_loss: 0.0372 - val_y_note_output_loss: 0.0079 - val_y_dur_output_loss: 0.0293
# Epoch 134/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0372 - y_note_output_loss: 0.0079 - y_dur_output_loss: 0.0293 - val_loss: 0.0357 - val_y_note_output_loss: 0.0077 - val_y_dur_output_loss: 0.0280
# Epoch 135/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0361 - y_note_output_loss: 0.0077 - y_dur_output_loss: 0.0284 - val_loss: 0.0360 - val_y_note_output_loss: 0.0080 - val_y_dur_output_loss: 0.0280
# Epoch 136/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0360 - y_note_output_loss: 0.0077 - y_dur_output_loss: 0.0284 - val_loss: 0.0351 - val_y_note_output_loss: 0.0079 - val_y_dur_output_loss: 0.0271
# Epoch 137/200
# 36/36 [==============================] - 7s 201ms/step - loss: 0.0360 - y_note_output_loss: 0.0076 - y_dur_output_loss: 0.0283 - val_loss: 0.0357 - val_y_note_output_loss: 0.0081 - val_y_dur_output_loss: 0.0277
# Epoch 138/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0355 - y_note_output_loss: 0.0076 - y_dur_output_loss: 0.0279 - val_loss: 0.0351 - val_y_note_output_loss: 0.0077 - val_y_dur_output_loss: 0.0275
# Epoch 139/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0352 - y_note_output_loss: 0.0074 - y_dur_output_loss: 0.0278 - val_loss: 0.0355 - val_y_note_output_loss: 0.0079 - val_y_dur_output_loss: 0.0276
# Epoch 140/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0353 - y_note_output_loss: 0.0075 - y_dur_output_loss: 0.0278 - val_loss: 0.0366 - val_y_note_output_loss: 0.0078 - val_y_dur_output_loss: 0.0288
# Epoch 141/200
# 36/36 [==============================] - 7s 201ms/step - loss: 0.0361 - y_note_output_loss: 0.0078 - y_dur_output_loss: 0.0283 - val_loss: 0.0358 - val_y_note_output_loss: 0.0078 - val_y_dur_output_loss: 0.0280
# Epoch 142/200
# 36/36 [==============================] - 7s 201ms/step - loss: 0.0354 - y_note_output_loss: 0.0075 - y_dur_output_loss: 0.0279 - val_loss: 0.0355 - val_y_note_output_loss: 0.0076 - val_y_dur_output_loss: 0.0278
# Epoch 143/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0347 - y_note_output_loss: 0.0074 - y_dur_output_loss: 0.0273 - val_loss: 0.0351 - val_y_note_output_loss: 0.0078 - val_y_dur_output_loss: 0.0273
# Epoch 144/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0348 - y_note_output_loss: 0.0074 - y_dur_output_loss: 0.0274 - val_loss: 0.0353 - val_y_note_output_loss: 0.0077 - val_y_dur_output_loss: 0.0275
# Epoch 145/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0355 - y_note_output_loss: 0.0076 - y_dur_output_loss: 0.0279 - val_loss: 0.0360 - val_y_note_output_loss: 0.0078 - val_y_dur_output_loss: 0.0282
# Epoch 146/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0352 - y_note_output_loss: 0.0076 - y_dur_output_loss: 0.0276 - val_loss: 0.0349 - val_y_note_output_loss: 0.0077 - val_y_dur_output_loss: 0.0272
# Epoch 147/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0357 - y_note_output_loss: 0.0076 - y_dur_output_loss: 0.0281 - val_loss: 0.0375 - val_y_note_output_loss: 0.0083 - val_y_dur_output_loss: 0.0292
# Epoch 148/200
# 36/36 [==============================] - 7s 201ms/step - loss: 0.0356 - y_note_output_loss: 0.0075 - y_dur_output_loss: 0.0282 - val_loss: 0.0372 - val_y_note_output_loss: 0.0081 - val_y_dur_output_loss: 0.0292
# Epoch 149/200
# 36/36 [==============================] - 7s 201ms/step - loss: 0.0354 - y_note_output_loss: 0.0075 - y_dur_output_loss: 0.0278 - val_loss: 0.0362 - val_y_note_output_loss: 0.0086 - val_y_dur_output_loss: 0.0276
# Epoch 150/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0350 - y_note_output_loss: 0.0076 - y_dur_output_loss: 0.0274 - val_loss: 0.0354 - val_y_note_output_loss: 0.0077 - val_y_dur_output_loss: 0.0276
# Epoch 151/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0344 - y_note_output_loss: 0.0073 - y_dur_output_loss: 0.0271 - val_loss: 0.0359 - val_y_note_output_loss: 0.0084 - val_y_dur_output_loss: 0.0275
# Epoch 152/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0342 - y_note_output_loss: 0.0073 - y_dur_output_loss: 0.0269 - val_loss: 0.0350 - val_y_note_output_loss: 0.0079 - val_y_dur_output_loss: 0.0271
# Epoch 153/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0345 - y_note_output_loss: 0.0075 - y_dur_output_loss: 0.0270 - val_loss: 0.0350 - val_y_note_output_loss: 0.0077 - val_y_dur_output_loss: 0.0274
# Epoch 154/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0342 - y_note_output_loss: 0.0073 - y_dur_output_loss: 0.0269 - val_loss: 0.0354 - val_y_note_output_loss: 0.0080 - val_y_dur_output_loss: 0.0275
# Epoch 155/200
# 36/36 [==============================] - 7s 201ms/step - loss: 0.0340 - y_note_output_loss: 0.0072 - y_dur_output_loss: 0.0268 - val_loss: 0.0361 - val_y_note_output_loss: 0.0081 - val_y_dur_output_loss: 0.0280
# Epoch 156/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0339 - y_note_output_loss: 0.0073 - y_dur_output_loss: 0.0267 - val_loss: 0.0353 - val_y_note_output_loss: 0.0080 - val_y_dur_output_loss: 0.0273
# Epoch 157/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0341 - y_note_output_loss: 0.0072 - y_dur_output_loss: 0.0269 - val_loss: 0.0344 - val_y_note_output_loss: 0.0076 - val_y_dur_output_loss: 0.0268
# Epoch 158/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0341 - y_note_output_loss: 0.0072 - y_dur_output_loss: 0.0269 - val_loss: 0.0363 - val_y_note_output_loss: 0.0079 - val_y_dur_output_loss: 0.0284
# Epoch 159/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0340 - y_note_output_loss: 0.0072 - y_dur_output_loss: 0.0269 - val_loss: 0.0378 - val_y_note_output_loss: 0.0075 - val_y_dur_output_loss: 0.0303
# Epoch 160/200
# 36/36 [==============================] - 7s 201ms/step - loss: 0.0376 - y_note_output_loss: 0.0079 - y_dur_output_loss: 0.0297 - val_loss: 0.0377 - val_y_note_output_loss: 0.0080 - val_y_dur_output_loss: 0.0297
# Epoch 161/200
# 36/36 [==============================] - 7s 199ms/step - loss: 0.0344 - y_note_output_loss: 0.0075 - y_dur_output_loss: 0.0269 - val_loss: 0.0347 - val_y_note_output_loss: 0.0076 - val_y_dur_output_loss: 0.0270
# Epoch 162/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0336 - y_note_output_loss: 0.0071 - y_dur_output_loss: 0.0265 - val_loss: 0.0357 - val_y_note_output_loss: 0.0078 - val_y_dur_output_loss: 0.0279
# Epoch 163/200
# 36/36 [==============================] - 7s 201ms/step - loss: 0.0336 - y_note_output_loss: 0.0071 - y_dur_output_loss: 0.0265 - val_loss: 0.0342 - val_y_note_output_loss: 0.0075 - val_y_dur_output_loss: 0.0267
# Epoch 164/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0335 - y_note_output_loss: 0.0071 - y_dur_output_loss: 0.0264 - val_loss: 0.0369 - val_y_note_output_loss: 0.0083 - val_y_dur_output_loss: 0.0286
# Epoch 165/200
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0339 - y_note_output_loss: 0.0071 - y_dur_output_loss: 0.0267 - val_loss: 0.0342 - val_y_note_output_loss: 0.0076 - val_y_dur_output_loss: 0.0266
# Epoch 166/200
# 36/36 [==============================] - 7s 201ms/step - loss: 0.0340 - y_note_output_loss: 0.0072 - y_dur_output_loss: 0.0268 - val_loss: 0.0357 - val_y_note_output_loss: 0.0078 - val_y_dur_output_loss: 0.0279
# Epoch 167/200
# 36/36 [==============================] - 7s 206ms/step - loss: 0.0346 - y_note_output_loss: 0.0072 - y_dur_output_loss: 0.0274 - val_loss: 0.0357 - val_y_note_output_loss: 0.0078 - val_y_dur_output_loss: 0.0279
# Epoch 168/200
# 36/36 [==============================] - 7s 203ms/step - loss: 0.0339 - y_note_output_loss: 0.0072 - y_dur_output_loss: 0.0267 - val_loss: 0.0355 - val_y_note_output_loss: 0.0084 - val_y_dur_output_loss: 0.0271
# Epoch 169/200
# 36/36 [==============================] - 7s 203ms/step - loss: 0.0357 - y_note_output_loss: 0.0077 - y_dur_output_loss: 0.0280 - val_loss: 0.0363 - val_y_note_output_loss: 0.0088 - val_y_dur_output_loss: 0.0274
# Epoch 170/200
# 36/36 [==============================] - 7s 192ms/step - loss: 0.0333 - y_note_output_loss: 0.0070 - y_dur_output_loss: 0.0263 - val_loss: 0.0347 - val_y_note_output_loss: 0.0076 - val_y_dur_output_loss: 0.0272
# Epoch 171/200
# 36/36 [==============================] - 7s 194ms/step - loss: 0.0344 - y_note_output_loss: 0.0072 - y_dur_output_loss: 0.0273 - val_loss: 0.0342 - val_y_note_output_loss: 0.0076 - val_y_dur_output_loss: 0.0266
# Epoch 172/200
# 36/36 [==============================] - 7s 193ms/step - loss: 0.0333 - y_note_output_loss: 0.0071 - y_dur_output_loss: 0.0262 - val_loss: 0.0360 - val_y_note_output_loss: 0.0078 - val_y_dur_output_loss: 0.0282
# Epoch 173/200
# 36/36 [==============================] - 7s 192ms/step - loss: 0.0344 - y_note_output_loss: 0.0075 - y_dur_output_loss: 0.0269 - val_loss: 0.0355 - val_y_note_output_loss: 0.0081 - val_y_dur_output_loss: 0.0274
# Epoch 174/200
# 36/36 [==============================] - 7s 192ms/step - loss: 0.0330 - y_note_output_loss: 0.0070 - y_dur_output_loss: 0.0260 - val_loss: 0.0351 - val_y_note_output_loss: 0.0075 - val_y_dur_output_loss: 0.0276
# Epoch 175/200
# 36/36 [==============================] - 7s 192ms/step - loss: 0.0328 - y_note_output_loss: 0.0070 - y_dur_output_loss: 0.0259 - val_loss: 0.0364 - val_y_note_output_loss: 0.0077 - val_y_dur_output_loss: 0.0286
# Epoch 176/200
# 36/36 [==============================] - 7s 192ms/step - loss: 0.0328 - y_note_output_loss: 0.0070 - y_dur_output_loss: 0.0257 - val_loss: 0.0359 - val_y_note_output_loss: 0.0088 - val_y_dur_output_loss: 0.0271
# Epoch 177/200
# 36/36 [==============================] - 7s 193ms/step - loss: 0.0330 - y_note_output_loss: 0.0070 - y_dur_output_loss: 0.0260 - val_loss: 0.0593 - val_y_note_output_loss: 0.0094 - val_y_dur_output_loss: 0.0498
# Epoch 178/200
# 36/36 [==============================] - 7s 193ms/step - loss: 0.0455 - y_note_output_loss: 0.0093 - y_dur_output_loss: 0.0363 - val_loss: 0.0396 - val_y_note_output_loss: 0.0083 - val_y_dur_output_loss: 0.0313
# Epoch 179/200
# 36/36 [==============================] - 7s 193ms/step - loss: 0.0374 - y_note_output_loss: 0.0078 - y_dur_output_loss: 0.0296 - val_loss: 0.0342 - val_y_note_output_loss: 0.0075 - val_y_dur_output_loss: 0.0267
# Epoch 180/200
# 36/36 [==============================] - 7s 192ms/step - loss: 0.0356 - y_note_output_loss: 0.0073 - y_dur_output_loss: 0.0283 - val_loss: 0.0347 - val_y_note_output_loss: 0.0080 - val_y_dur_output_loss: 0.0267
# Epoch 181/200
# 36/36 [==============================] - 7s 193ms/step - loss: 0.0342 - y_note_output_loss: 0.0072 - y_dur_output_loss: 0.0270 - val_loss: 0.0338 - val_y_note_output_loss: 0.0078 - val_y_dur_output_loss: 0.0260
# Epoch 182/200
# 36/36 [==============================] - 7s 192ms/step - loss: 0.0338 - y_note_output_loss: 0.0070 - y_dur_output_loss: 0.0268 - val_loss: 0.0340 - val_y_note_output_loss: 0.0075 - val_y_dur_output_loss: 0.0264
# Epoch 183/200
# 36/36 [==============================] - 7s 193ms/step - loss: 0.0333 - y_note_output_loss: 0.0068 - y_dur_output_loss: 0.0265 - val_loss: 0.0345 - val_y_note_output_loss: 0.0074 - val_y_dur_output_loss: 0.0270
# Epoch 184/200
# 36/36 [==============================] - 7s 193ms/step - loss: 0.0331 - y_note_output_loss: 0.0068 - y_dur_output_loss: 0.0263 - val_loss: 0.0346 - val_y_note_output_loss: 0.0079 - val_y_dur_output_loss: 0.0267
# Epoch 185/200
# 36/36 [==============================] - 7s 193ms/step - loss: 0.0331 - y_note_output_loss: 0.0068 - y_dur_output_loss: 0.0263 - val_loss: 0.0343 - val_y_note_output_loss: 0.0077 - val_y_dur_output_loss: 0.0266
# Epoch 186/200
# 36/36 [==============================] - 7s 193ms/step - loss: 0.0327 - y_note_output_loss: 0.0068 - y_dur_output_loss: 0.0259 - val_loss: 0.0345 - val_y_note_output_loss: 0.0079 - val_y_dur_output_loss: 0.0266
# Epoch 187/200
# 36/36 [==============================] - 7s 193ms/step - loss: 0.0327 - y_note_output_loss: 0.0068 - y_dur_output_loss: 0.0259 - val_loss: 0.0362 - val_y_note_output_loss: 0.0085 - val_y_dur_output_loss: 0.0277
# Epoch 188/200
# 36/36 [==============================] - 7s 194ms/step - loss: 0.0326 - y_note_output_loss: 0.0068 - y_dur_output_loss: 0.0258 - val_loss: 0.0347 - val_y_note_output_loss: 0.0077 - val_y_dur_output_loss: 0.0270
# Epoch 189/200
# 36/36 [==============================] - 7s 193ms/step - loss: 0.0322 - y_note_output_loss: 0.0067 - y_dur_output_loss: 0.0255 - val_loss: 0.0347 - val_y_note_output_loss: 0.0077 - val_y_dur_output_loss: 0.0269
# Epoch 190/200
# 36/36 [==============================] - 7s 193ms/step - loss: 0.0325 - y_note_output_loss: 0.0070 - y_dur_output_loss: 0.0255 - val_loss: 0.0352 - val_y_note_output_loss: 0.0081 - val_y_dur_output_loss: 0.0271
# Epoch 191/200
# 36/36 [==============================] - 7s 192ms/step - loss: 0.0322 - y_note_output_loss: 0.0067 - y_dur_output_loss: 0.0255 - val_loss: 0.0345 - val_y_note_output_loss: 0.0075 - val_y_dur_output_loss: 0.0270
# Epoch 192/200
# 36/36 [==============================] - 7s 193ms/step - loss: 0.0316 - y_note_output_loss: 0.0066 - y_dur_output_loss: 0.0250 - val_loss: 0.0357 - val_y_note_output_loss: 0.0076 - val_y_dur_output_loss: 0.0281
# Epoch 193/200
# 36/36 [==============================] - 7s 192ms/step - loss: 0.0322 - y_note_output_loss: 0.0066 - y_dur_output_loss: 0.0255 - val_loss: 0.0343 - val_y_note_output_loss: 0.0078 - val_y_dur_output_loss: 0.0265
# Epoch 194/200
# 36/36 [==============================] - 7s 191ms/step - loss: 0.0317 - y_note_output_loss: 0.0066 - y_dur_output_loss: 0.0251 - val_loss: 0.0360 - val_y_note_output_loss: 0.0076 - val_y_dur_output_loss: 0.0285
# Epoch 195/200
# 36/36 [==============================] - 7s 193ms/step - loss: 0.0395 - y_note_output_loss: 0.0077 - y_dur_output_loss: 0.0318 - val_loss: 0.0354 - val_y_note_output_loss: 0.0079 - val_y_dur_output_loss: 0.0275
# Epoch 196/200
# 36/36 [==============================] - 7s 192ms/step - loss: 0.0332 - y_note_output_loss: 0.0069 - y_dur_output_loss: 0.0263 - val_loss: 0.0336 - val_y_note_output_loss: 0.0076 - val_y_dur_output_loss: 0.0260
# Epoch 197/200
# 36/36 [==============================] - 7s 193ms/step - loss: 0.0322 - y_note_output_loss: 0.0068 - y_dur_output_loss: 0.0255 - val_loss: 0.0342 - val_y_note_output_loss: 0.0077 - val_y_dur_output_loss: 0.0265
# Epoch 198/200
# 36/36 [==============================] - 7s 194ms/step - loss: 0.0319 - y_note_output_loss: 0.0067 - y_dur_output_loss: 0.0251 - val_loss: 0.0346 - val_y_note_output_loss: 0.0078 - val_y_dur_output_loss: 0.0268
# Epoch 199/200
# 36/36 [==============================] - 7s 194ms/step - loss: 0.0319 - y_note_output_loss: 0.0067 - y_dur_output_loss: 0.0252 - val_loss: 0.0341 - val_y_note_output_loss: 0.0075 - val_y_dur_output_loss: 0.0266
# Epoch 200/200
# 36/36 [==============================] - 7s 192ms/step - loss: 0.0315 - y_note_output_loss: 0.0065 - y_dur_output_loss: 0.0250 - val_loss: 0.0344 - val_y_note_output_loss: 0.0076 - val_y_dur_output_loss: 0.0268
# 38/38 [==============================] - 2s 44ms/step - loss: 0.0350 - y_note_output_loss: 0.0082 - y_dur_output_loss: 0.0269

# %%
# Save the model
model.save('./models/model_rnn_gru.h5')
# Out:
# c:\Users\Niko\anaconda3\envs\ProjectVivy\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # 4. Validation
# Put user input and get output

# %% [markdown]
# ### 4.1 Input

# %%
import json
import joblib
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Load the encoding dictionary from the ph_token_to_int.json file
with open('ph_token_to_int.json', 'r') as file:
    ph_token_to_int = json.load(file)

# Input sequence
input_sequence = "AP n ei f a g e n a j i f u y u a p u AP n ei f a g e n a l e y u d ao en AP"

# Split the input sequence into individual phonemes
input_phonemes = input_sequence.split()

# Convert the phonemes to their corresponding integers using the encoding dictionary
encoded_sequence = [ph_token_to_int[phoneme] for phoneme in input_phonemes]

# Convert the sequence to a numpy array and pad it to the right length
ph_seq_encoded = np.array([encoded_sequence]) 

user_input = pad_sequences(ph_seq_encoded, maxlen=283, padding='post', truncating='post', dtype='float64')

# %% [markdown]
# ### 4.2 Inference

# %%
# Prediction
y_note_pred, y_dur_pred = model.predict(user_input)
print(y_note_pred.shape, y_note_pred.shape)
# Out:
# WARNING:tensorflow:6 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001120370B820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 842ms/step
# (1, 283, 1) (1, 283, 1)

# %% [markdown]
# ### 4.3 Decoding

# %%
# Resize the result
input_length = len(encoded_sequence)
y_note_pred = y_note_pred[:, :input_length, :]
y_dur_pred = y_dur_pred[:, :input_length, :]

# print(y_note_pred.shape, y_dur_pred.shape)

# Load the saved scaler
note_scaler = joblib.load('note_scaler.pkl')

y_note_pred_flattened = y_note_pred.flatten()

# Inverse transform the predictions
y_note_pred_original = note_scaler.inverse_transform(y_note_pred_flattened.reshape(-1, 1))

# Reshape back to the original shape if required
y_note_pred_original = y_note_pred_original.reshape(y_note_pred.shape)
y_note_pred_original = np.round(y_note_pred_original).astype(int)

f0_timestep = 0.005
f0_seq_constant = 250.1

total_time = np.sum(y_dur_pred)
print(total_time)
f0_size = int(total_time / f0_timestep)
# print(f0_size)

f0_seq = [f0_seq_constant] * f0_size
# Out:
# 13.599577

# %% [markdown]
# ### 4.5 Make it .ds file

# %%
y_note_pred_flattened = y_note_pred_original[0]
y_note_pred_output = [int(i) for i in y_note_pred_flattened]

y_dur_pred_flattened = y_dur_pred[0]
y_dur_pred_output = [float(i) for i in y_dur_pred_flattened]

# Load the token-to-int mappings from the JSON files
def load_mapping(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        token_to_int = json.load(f)
    # Invert the dictionary to create an int-to-token mapping
    int_to_token = {v: k for k, v in token_to_int.items()}
    return int_to_token

# Decoding function using the mappings
def decode_predictions(prediction_integers, mapping):
    return [mapping.get(i, 'Unknown') for i in prediction_integers]

note_int_to_token = load_mapping('note_token_to_int.json')

decoded_note_seq = decode_predictions(y_note_pred_output, note_int_to_token)

# Print or return the decoded sequences
# print("Decoded Phonetic Sequence:", input_phonemes)
# print("Decoded Note Sequence:", decoded_note_seq)

ph_dur = ' '.join(map(str, y_dur_pred_output))
note_seq = ' '.join(map(str, decoded_note_seq))
f0_seq = ' '.join(map(str, f0_seq))

file = {
    'ph_seq': input_sequence,
    'ph_dur': ph_dur,
    'note_seq': note_seq,
    'f0_seq': f0_seq,
    'f0_timestep': f0_timestep
}

with open('rnn_gru_output.ds', 'w') as json_file:
    json.dump(file, json_file, indent=4)
# Out:
# C:\Users\Niko\AppData\Local\Temp\ipykernel_8556\4290103554.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y_note_pred_output = [int(i) for i in y_note_pred_flattened]
# C:\Users\Niko\AppData\Local\Temp\ipykernel_8556\4290103554.py:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y_dur_pred_output = [float(i) for i in y_dur_pred_flattened]
